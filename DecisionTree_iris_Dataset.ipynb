# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshithreddy2004/LMS/blob/main/DecisionTree_iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
file_path=("/content/drive/MyDrive/iris.csv")
pd=pd.read_csv(file_path)
pd.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
iris = pd.rename(columns={'Species':'flowers_types'})
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#     flowers_types
# 0          setosa
# 1          setosa
# 2          setosa
# 3          setosa
# 4          setosa
# ...

# %%
iris.drop('Unnamed: 0',axis=1,inplace=True)
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width flowers_types
# 0             5.1          3.5           1.4          0.2        setosa
# 1             4.9          3.0           1.4          0.2        setosa
# 2             4.7          3.2           1.3          0.2        setosa
# 3             4.6          3.1           1.5          0.2        setosa
# 4             5.0          3.6           1.4          0.2        setosa
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3     virginica
# 146           6.3          2.5           5.0          1.9     virginica
# 147           6.5          3.0           5.2          2.0     virginica
# 148           6.2          3.4           5.4          2.3     virginica
# 149           5.9          3.0           5.1          1.8     virginica
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.preprocessing import LabelEncoder

# %%
label_encoding = LabelEncoder()
# Use 'flowers_types' instead of 'Species' since you renamed the column
iris['flowers_types'] = label_encoding.fit_transform(iris['flowers_types'])
iris['flowers_types']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: flowers_types, Length: 150, dtype: int64

# %%
x=iris.iloc[:,0:4]
y=iris['flowers_types']

# %%
x
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
pd.count(1)
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 145    5
# 146    5
# 147    5
# 148    5
# 149    5
# Length: 150, dtype: int64

# %%
iris['flowers_types'].unique()
# Out:
# array([0, 1, 2])

# %%
iris.flowers_types.value_counts()
# Out:
# flowers_types
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
columns = list(iris.columns)
columns
# Out:
# ['Sepal.Length',
#  'Sepal.Width',
#  'Petal.Length',
#  'Petal.Width',
#  'flowers_types',
#  'flowers_Tpyes']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %% [markdown]
# Building Decision Tree Classifier using Entropy Criteria

# %%
from sklearn.tree import DecisionTreeClassifier
model =DecisionTreeClassifier(criterion='entropy',max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
tree.plot_tree(model)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\nentropy = 1.584\nsamples = 120\nvalue = [42, 38, 40]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[3] <= 1.75\nentropy = 1.0\nsamples = 78\nvalue = [0, 38, 40]'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'x[2] <= 4.95\nentropy = 0.527\nsamples = 42\nvalue = [0, 37, 5]'),
#  Text(0.125, 0.125, 'entropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.375, 0.125, 'entropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\nentropy = 0.183\nsamples = 36\nvalue = [0, 1, 35]'),
#  Text(0.625, 0.125, 'entropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]')]

# %%
fn=['sepal_length','sepal_width','petal_length','petal_width']
cn=['setosa','versicolor','virginica']
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(4,4),dpi=300)
tree.plot_tree(model,
               feature_names=fn,
               class_names=cn,
               filled=True)
# Out:
# [Text(0.375, 0.875, 'petal_length <= 2.45\nentropy = 1.584\nsamples = 120\nvalue = [42, 38, 40]\nclass = setosa'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 42\nvalue = [42, 0, 0]\nclass = setosa'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal_width <= 1.75\nentropy = 1.0\nsamples = 78\nvalue = [0, 38, 40]\nclass = virginica'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'petal_length <= 4.95\nentropy = 0.527\nsamples = 42\nvalue = [0, 37, 5]\nclass = versicolor'),
#  Text(0.125, 0.125, 'entropy = 0.183\nsamples = 36\nvalue = [0, 35, 1]\nclass = versicolor'),
#  Text(0.375, 0.125, 'entropy = 0.918\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(0.75, 0.375, 'petal_length <= 4.85\nentropy = 0.183\nsamples = 36\nvalue = [0, 1, 35]\nclass = virginica'),
#  Text(0.625, 0.125, 'entropy = 1.0\nsamples = 2\nvalue = [0, 1, 1]\nclass = versicolor'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 34\nvalue = [0, 0, 34]\nclass = virginica')]
